# %%
# %pip install -qq --upgrade ../dsd
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -qq -e .
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import scanpy as sc

# %%
import scorphan as so

# %%
import dsd

# %%
adata = sc.datasets.pbmc3k()

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 2700 × 32738
#     var: 'gene_ids'

# %%
# from dsd import scrnaseq

# %%
dsd.scrnaseq.std_quality_control_anndata(adata)

# %%
dsd.scrnaseq.std_process(adata)

# %%
sc.pp.pca(adata)
sc.pp.neighbors(adata)
sc.tl.leiden(adata, flavor="igraph", n_iterations=2)
sc.tl.umap(adata)

# %%
sc.pl.umap(adata, color="leiden")

# %%
from pathlib import Path

# %%
so.tl.GSEApy_process(adata, obs_subset=adata.obs.query("leiden in ['0', '1']").index, groupby="leiden", referencegroup="0", wanted_group="1", outdir_path=Path("./GSEA_results_auto/"), verbose=True)
# Out:
# scorphan._tools:GSEApy_process:124 - No geneset was specified. Using the three GeneOntology groups
# scorphan._tools:GSEApy_process:134 - subsetting anndata obj
# scorphan._tools:GSEApy_process:142 - normalizing and log transforming data
# WARNING: adata.X seems to be already log-transformed.
# scorphan._tools:GSEApy_process:153 - inflating sparse counts
# scorphan._tools:GSEApy_process:157 - Performing GSEA
# 2024-09-16 13:38:12,967 [INFO] Parsing data files for GSEA.............................
# /home/milo/workspace/scorphan/.venv/lib/python3.11/site-packages/gseapy/gsea.py:110: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df_std = df.groupby(by=cls_dict, axis=1).std(numeric_only=True, ddof=0)
# /home/milo/workspace/scorphan/.venv/lib/python3.11/site-packages/gseapy/gsea.py:116: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df = df[df_std.abs().sum(axis=1) > 0]
# ...
